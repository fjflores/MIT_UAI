# %% [markdown]
# # Module 2, Lecture 4: Type Abstruction

# %% [markdown]
# ### Plotting Setup
#
# This section imports the necessary libraries (`matplotlib`, `datetime`, `relativedelta`, `random`, `sys`) and configures **plot aesthetics** using `plt.rcParams`.
#
# - **Line width:** 4
# - **Font sizes:** titles (12), axis labels (12), x-ticks (10), y-ticks (12)
# - **Tick sizes:** x-axis (7), y-axis (7)
# - **Legend:** one point per entry, font size (8)
# - **Markers:** size 6
#
# These settings ensure that all plots in the lecture are clear, consistent, and easy to read.

# %%
import matplotlib.pyplot as plt
from datetime import date
from dateutil.relativedelta import relativedelta
import random
import sys

# set line width
plt.rcParams['lines.linewidth'] = 4
# set font size for titles
plt.rcParams['axes.titlesize'] = 12
# set font size for labels on axes
plt.rcParams['axes.labelsize'] = 12
# set size of numbers on x-axis
plt.rcParams['xtick.labelsize'] = 10
# set size of numbers on y-axis
plt.rcParams['ytick.labelsize'] = 12
# set size of ticks on x-axis
plt.rcParams['xtick.major.size'] = 7
# set size of ticks on y-axis
plt.rcParams['ytick.major.size'] = 7
# set numpoints for legend``
plt.rcParams['legend.numpoints'] = 1
# set fontsize for legend
plt.rcParams['legend.fontsize'] = 8
# set marker size
plt.rcParams['lines.markersize'] = 6

# %% [markdown]
# ### The `Fraction` Class
#
# This class defines an **immutable rational number** type in Python.
#
# - **Initialization:**
#   - Stores numerator and denominator in a list (`self.val`).
#   - Denominator must be nonzero.
#
# - **Custom methods:**
#   - `lt()` and `mul()`: early versions of comparison and multiplication.
#   - Replaced by Python’s **dunder methods** for operator overloading.
#
# - **Dunder methods:**
#   - `__lt__`: enables `<` comparisons between fractions.
#   - `__mul__`, `__truediv__`, `__add__`, `__sub__`: implement `*`, `/`, `+`, `-`.
#   - `__float__`: converts a fraction to a `float`.
#   - `__str__`: prints the fraction in **reduced form** (using GCD).

# %%
class Fraction(object):
    """
    A rational number represented as a fraction.
    Fractions are immutable.
    """
    def __init__(self, num, denom):
        """ num and denom are integers, denom != 0"""
        self.val = [num, denom]

    def lt(self, other):
        """Returns true if self < other, false otherwise"""
        return self.val[0]/self.val[1] < other.val[0]/other.val[1]
    
    def mul(self, other):
        """ Returns a new fraction representing the
            multiplication of self and other"""
        top = self.val[0]*other.val[0]
        bottom = self.val[1]*other.val[1]
        return Fraction(top, bottom)
    
    def __lt__(self, other):
        """Returns true if self < other, false otherwise"""
        return self.val[0]/self.val[1] < other.val[0]/other.val[1]
    
    def __mul__(self, other):
        """ Returns a new fraction representing the
            multiplication of self and other"""
        top = self.val[0]*other.val[0]
        bottom = self.val[1]*other.val[1]
        return Fraction(top, bottom)
    
    def __truediv__(self, other):
        """ Returns a new fraction representing dividing
            self by other"""
        top = self.val[0]*other.val[1]
        bottom = self.val[1]*other.val[0]
        return Fraction(top, bottom)
    
    def __add__(self, other):
        """ Returns a new fraction representing the
            addition of self and other"""
        top = self.val[0]*other.val[1] + other.val[0]*self.val[1]
        bottom = self.val[1]*other.val[1]
        return Fraction(top, bottom)
    
    def __sub__(self, other):
        """ Returns a new fraction representing the
            subtraction of other from self"""
        top = self.val[0]*other.val[1] - self.val[1]*other.val[0]
        bottom = self.val[1]*other.val[1]
        return Fraction(top, bottom)
    
    def __float__(self):
        return self.val[0]/self.val[1]
    
    def __str__(self):
        """Returns a string representation of the fraction
           The fraction is fully reduced."""
        def reduce(self):
            def gcd(n, d):
                while d != 0:
                    (d, n) = (n%d, d)
                return n
            greatest_common_divisor = gcd(self.val[0],self.val[1])
            top = int(self.val[0]/greatest_common_divisor)
            bottom = int(self.val[1]/greatest_common_divisor)
            return top, bottom
        top, bottom = reduce(self)
        return str(top) +'/' + str(bottom)

# %% [markdown]
# ### Using Fractions
#
# - `mul()` / `lt()` work, but operators (`*`, `<`) via dunder methods are cleaner.
# - Fractions handle negatives and convert to `float` with `__float__`.
# - Fractions give **exact arithmetic** (e.g., 1/10 + … + 1/10 = 1), unlike floating point (~0.9999).

# %%
f1 = Fraction(1,2)
f2 = f1.mul(f1)
print(f1.lt(f2))

f1 = Fraction(1,2)
f2 = f1*f1
print(f1 < f2)

f1 = Fraction(-1,2)
f2 = Fraction(2,3)
print(f1*f2)

print(f'The floating point representation of {f2} is {float(f2)}.')

num = 0
frac = Fraction(0, 1)
for _ in range(10):
    num += 0.1
    frac += Fraction(1, 10)
print(f'num = {num}')
print(f'frac = {frac} = {float(frac)}')
# Out:
# False
# False
# -1/3
# The floating point representation of 2/3 is 0.6666666666666666.
# num = 0.9999999999999999
# frac = 1/1 = 1.0

# %% [markdown]
# ### `Transaction` (immutable)
# - Records a single event: **'Initial loan'**, **'Payment'**, or **'Accrued interest'**.
# - Stores `{date, description, amount}`; payments are negative internally.
# - Key methods: `get_date()`, `get_payment_amt()` (positive for payments), `get_amount()`, `__str__()`.
#
# ### `Ledger` (mutable)
# - Tracks a loan’s **history**: `transactions` and running **balances**.
# - Starts with the initial loan; `add_transaction()` updates both log and balance.
# - Key methods: `get_balances()`, `get_dates()`, `get_total_paid()`, `__str__()`.
#
# ### `Loan` (mutable, fixed-rate, no set schedule)
# - State: `balance`, `annual_rate` (and `daily_rate`), `start_date`, `last_accrual`, and a `Ledger`.
# - Actions: `accrue_interest(current_date)` and `make_payment(amount, date)`.
# - Encapsulation: `_update_ledger()` is **private**; getters: `get_start_date()`, `get_balance()`, `get_annual_rate()`, `get_ledger()`.

# %%
class Transaction(object):
    """ An immutable type describing transactions related to loans"""
    
    def __init__(self, description, amount, date):
        """ description a string describing type of transaction. Must be one
              of 'Initial loan', 'Payment', 'Accrued interest'
            amount a number indicated value of transaction (negative for
              a Payment)
            date of type date is the date of the transaction
        """
        self.val = {'date': date, 'description': description,
                    'amount': amount}
    
    def get_date(self):
        """ returns the date of the transaction"""
        return self.val['date']
    
    def get_payment_amt(self):
        """ Returns the value of a loan payment transaction. Note this
            will be a positive number.
            For all other kinds of transactions returns 0
        """
        if self.val['description'] == 'Payment':
            return -self.val['amount']
        else:
            return 0
    
    def get_amount(self):
        """ Returns the amount of the transaction"""
        return self.val['amount']
    
    def __str__(self):
        """ returns a string describing the transaction"""
        date = self.val['date']
        description = self.val['description']
        if description == 'Payment':
            return f"{date}: Payment of ${abs(self.val['amount'])}"
        elif description == 'Accrued interest':
            return f"{date}: Accrued interest of ${self.val['amount']}"
        else:
            return f"\n\n{date}: Initial loan of ${self.val['amount']}"

# %%
class Ledger(object):
    """ A mutable type that records a sequence of transactions"""
    
    def __init__(self, title, principal, date):
        """ title a str, principal, a positive number, date a date
            creates a mutable ledger for a loan
        """
        self.title = title
        self.transactions = [Transaction('Initial loan', principal, date)]
        self.balances = [principal]
        
    def add_transaction(self, trans):
        """ adds a transaction to a ledger"""
        self.transactions.append(trans)
        self.balances.append(round(self.balances[-1] +
                                   trans.get_amount(), 2))
        
    def get_balances(self):
        """ returns a list with the the history of loan balances in the ledger"""
        return self.balances[:]
        
    def get_dates(self):
        """ returns a list with the the history of transactin dates"""
        return [t.get_date() for t in self.transactions]
    
    def get_total_paid(self):
        """ returns the sum of all loan payments recorded"""
        return sum([abs(t.get_payment_amt()) for t in self.transactions])
           
    def __str__(self):
        result = f'          Ledger for {self.title}'
        for i in range(len(self.transactions)):
            result += (f"{self.transactions[i]}, "
                       f"balance = {self.balances[i]}\n")
        return result[:-1]

# %%
class Loan(object):
    """ A mutable type for a fixed rate loan with no payment schedule
        or duration. Allows payments, accrues interest, and keeps a
        ledger of transactions
    """
        
    def __init__(self, principal, annual_rate, start_date, name):
        """principal and annual_rate non-negative numbers
           start_date an object of type date, name a str
        """
        self.annual_rate = annual_rate
        self.daily_rate = annual_rate / 365
        self.balance = principal
        self.ledger = Ledger(name, principal, start_date)
        self.start_date = start_date
        self.last_accrual = start_date

    def _update_ledger(self, description, amount, date):
        """ private method for updating ledger. Should not be called from
            outside of class
        """
        self.ledger.add_transaction(Transaction(description, amount, date))

    def accrue_interest(self, current_date):
        """accrues interest between the most recent interest accrual and
           current_date
        """
        days = (current_date - self.last_accrual).days
        if days > 0:
            interest = round(self.balance * self.daily_rate * days, 2)
            self.balance += interest
            self._update_ledger('Accrued interest', interest, current_date)
            self.last_accrual = current_date

    def make_payment(self, amount, date):
        """ make a payment of amount on date """
        self.balance -= amount
        self._update_ledger('Payment', -amount, date)

    def get_start_date(self):
        return self.start_date
        
    def get_balance(self):
        return round(self.balance, 2)
    
    def get_annual_rate(self):
        return self.annual_rate

    def get_ledger(self):
        return self.ledger

# %% [markdown]
# ### Using the `Loan` Class
#
# - **Create loan:** `$200` principal, `24%` annual rate, start date `1776-07-04`.
# - **Accrue interest:** Adds one month of interest (by `daily_rate`).
# - **Make payment:** Subtracts `$100` and updates the ledger.
# - **Check balance:** `get_balance()` shows the remaining amount after interest and payment.

# %%
# Create object of type loan with initial values
loan = Loan(principal = 200, annual_rate = 0.24,
                start_date = date(1776, 7, 4), name = 'Musket Loan')
# Mutate the loan object
loan.accrue_interest(date(1776, 8, 4))
# Mutate the loan object
loan.make_payment(100, date(1776, 8, 4))
# Extract and print information about the loan object
print(f'The remaining loan balance is ${loan.get_balance()}')
# Out:
# The remaining loan balance is $104.08

# %% [markdown]
# ### Loan Payment Simulation
#
# - **`make_payments(loan, payment_amt, payment_prob=1)`**
#   - Simulates monthly payments with probability of paying (`payment_prob`).
#   - Stops if debt grows faster than payments.
#   - Handles full or partial final payment.
#
# - **`simple_make_payments(loan, payment_amt)`**
#   - Deterministic version: assumes **every payment is made**.
#   - Loops until balance is fully repaid.

# %%
def make_payments(loan, payment_amt, payment_prob = 1):
    """ Simulate making series of of monthly loan payments of payment_amt
           until either balance is 0 or payment would not cover monthly
           accrued interest
        Each payment is made with a probability of payment_prob.
        
        Mutates loan
    """
    payment_date = loan.get_start_date() + relativedelta(months=1)
    while loan.get_balance() > 0:
        loan.accrue_interest(payment_date)
        balance = loan.get_balance()
        if balance*(loan.get_annual_rate()/12) > payment_amt:
            return # because debt will never stop growing
        if random.random() <= payment_prob:
            if balance < payment_amt:
                loan.make_payment(balance, payment_date)
            else:
                loan.make_payment(payment_amt, payment_date)
        payment_date = payment_date + relativedelta(months=1)

# %%
def simple_make_payments(loan, payment_amt):
    payment_date = loan.get_start_date() + relativedelta(months=1)
    while loan.get_balance() > 0:
        loan.accrue_interest(payment_date)
        balance = loan.get_balance()
        if balance < payment_amt:
            loan.make_payment(balance, payment_date)
        else:
            loan.make_payment(payment_amt, payment_date)
        payment_date = payment_date + relativedelta(months=1)

# %% [markdown]
# ### Very Simple Loan Test
#
# - Creates a $200 loan at 24% annual rate.
# - Pays $40 monthly until balance is cleared.
# - Uses the ledger to report **total paid** and **elapsed days**.

# %%
def very_simple_test():
    start_date = date(2025, 7, 1)
    principal = 200
    annual_rate = 0.24 # 2%/month
    title = f'Loan of ${principal} with annual rate {100*annual_rate}%'
    payment_amt = 40
    
    loan = Loan(principal = principal, annual_rate = annual_rate,
                    start_date = start_date, name = title)
    simple_make_payments(loan, payment_amt)
    ledger = loan.get_ledger()
    end_date = ledger.get_dates()[-1]
    total_paid = ledger.get_total_paid()
    elapsed_days = (end_date - start_date).days
    print(f'Total paid when monthly payment is ${payment_amt} = '
          f'${total_paid}.\nElapsed days = {elapsed_days}.')
    
very_simple_test()
# Out:
# Total paid when monthly payment is $40 = $213.04.
# Elapsed days = 184.

# %% [markdown]
# ### Simple Loan Test
#
# - **`simple_test`**: Creates a $200 loan at 24% annual rate, simulates monthly payments (`payment_amt`) with optional probability of missed payments.
#   - Prints the **ledger** if `verbose=1`.
#   - Reports **total paid** and **elapsed days**.
#
# - **`first_test`**: Runs `simple_test` with a $40 monthly payment and prints the full ledger.

# %%
def simple_test(title, payment_amt, payment_prob = 1, verbose = 0):
    """Try a simple loan"""
    start_date = date(2025, 7, 1)
    principal = 200
    annual_rate = 0.24 # 2%/month
    
    title = title + f' ${principal} with annual rate {100*annual_rate}%'
    loan = Loan(principal=principal, annual_rate=annual_rate,
                    start_date=start_date, name = title)
    make_payments(loan, payment_amt, payment_prob)
    ledger = loan.get_ledger()
    if verbose > 0:
        print(ledger)
    end_date = ledger.get_dates()[-1]
    total_paid = ledger.get_total_paid()
    elapsed_days = (end_date - start_date).days
    print(f'Total paid when monthly payment is ${payment_amt} = '
          f'${total_paid}.\nElapsed days = {elapsed_days}')

def first_test():
    """ Look at a ledger"""
    simple_test('Test 1: Loan', 40, verbose = 1)
    
first_test()
# Out:
#           Ledger for Test 1: Loan $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $40, balance = 164.08
# 2025-09-01: Accrued interest of $3.34, balance = 167.42
# 2025-09-01: Payment of $40, balance = 127.42
# 2025-10-01: Accrued interest of $2.51, balance = 129.93
# 2025-10-01: Payment of $40, balance = 89.93
# 2025-11-01: Accrued interest of $1.83, balance = 91.76
# 2025-11-01: Payment of $40, balance = 51.76
# 2025-12-01: Accrued interest of $1.02, balance = 52.78
# 2025-12-01: Payment of $40, balance = 12.78
# 2026-01-01: Accrued interest of $0.26, balance = 13.04
# 2026-01-01: Payment of $13.04, balance = 0.0
# Total paid when monthly payment is $40 = $213.04.
# Elapsed days = 184

# %% [markdown]
# ### Second Test
#
# Compares loans with different **monthly payment sizes** ($8, $16, $32) to show how payment amount affects **total cost** and **time to repay**.

# %%
def second_test():
    """ Compare different size monthly payments"""
    for payment_amt in [8, 16, 32]:
        simple_test('Test 2: Loan', payment_amt, verbose = 0)


second_test()
# Out:
# Total paid when monthly payment is $8 = $280.29.
# Elapsed days = 1096
# Total paid when monthly payment is $16 = $232.62.
# Elapsed days = 457
# Total paid when monthly payment is $32 = $216.01.
# Elapsed days = 215

# %% [markdown]
# ### Test with Missed Payments
#
# This test demonstrates how **payment reliability** affects loan outcomes.
#
# - A $200 loan at 24% annual interest is set up with ~$8 monthly payments.
# - Three scenarios are simulated:
#   - **Always pay (100%)** → loan paid off with modest interest.
#   - **Occasional misses (80%)** → repayment stretches longer, total cost rises.
#   - **Frequent misses (50%)** → debt may grow faster than it is repaid, leaving a **remaining balance**.
# - Results are plotted as debt balance over time, showing the dramatic effect of skipped payments.

# %%
def test_missing(verbose = 0):
    """Looks at impact of multiple probabilities of missing payments
       Produces plots
    """
    start_date = date(2025, 7, 1)
    principal = 200
    annual_rate = 0.24 # 2%/month
    # Plan to pay off in slighly more than 2 years
    payment_amt = round(principal/24)
    
    title = f'Loan of ${principal} with annual rate {100*annual_rate}%'
    for payment_prob in (1, 0.8, 0.5,):
        loan = Loan(principal=principal, annual_rate=annual_rate,
                        start_date=start_date, name = title)
        make_payments(loan, payment_amt, payment_prob)
        ledger = loan.get_ledger()
        if verbose > 0:
            print(ledger)
        label = (f'Payment prob. = {payment_prob}\n'
                f'Total paid = ${ledger.get_total_paid()}')
        if loan.get_balance() > 0:
            label += f'\nRemaining balance = {loan.get_balance()}'
        plt.plot(ledger.get_dates(), ledger.get_balances(),
                 label = label)
        plt.xticks(rotation = 90)
    plt.title(f'Paying Off a \${principal} {annual_rate*100}% Annual Rate '
              f'Loan at ${payment_amt}/month')
    plt.ylabel('Remaining Debt ($)')
    plt.legend()

test_missing()

# %% [markdown]
# ### Multiple Trials Test
#
# Runs the missed-payment simulation several times to show how **randomness** changes outcomes.
# Even with the same setup, different random sequences of missed payments can lead to very different repayment paths — from paying off the loan to spiraling debt.

# %%
def try_multiple_trials(verbose = False):
    """Run multipe trials of test"""
    num_trials = 4
    random.seed(0)
    for t in range(num_trials):
        test_missing(verbose)
        if t < num_trials - 1:
            plt.figure()

try_multiple_trials(True)
# Out:
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-10-01: Payment of $8, balance = 187.87
# 2025-11-01: Accrued interest of $3.83, balance = 191.7
# 2025-11-01: Payment of $8, balance = 183.7
# 2025-12-01: Accrued interest of $3.62, balance = 187.32
# 2025-12-01: Payment of $8, balance = 179.32
# 2026-01-01: Accrued interest of $3.66, balance = 182.98
# 2026-01-01: Payment of $8, balance = 174.98
# 2026-02-01: Accrued interest of $3.57, balance = 178.55
# 2026-02-01: Payment of $8, balance = 170.55
# 2026-03-01: Accrued interest of $3.14, balance = 173.69
# 2026-03-01: Payment of $8, balance = 165.69
# 2026-04-01: Accrued interest of $3.38, balance = 169.07
# 2026-04-01: Payment of $8, balance = 161.07
# 2026-05-01: Accrued interest of $3.18, balance = 164.25
# 2026-05-01: Payment of $8, balance = 156.25
# 2026-06-01: Accrued interest of $3.18, balance = 159.43
# 2026-06-01: Payment of $8, balance = 151.43
# 2026-07-01: Accrued interest of $2.99, balance = 154.42
# 2026-07-01: Payment of $8, balance = 146.42
# 2026-08-01: Accrued interest of $2.98, balance = 149.4
# 2026-08-01: Payment of $8, balance = 141.4
# 2026-09-01: Accrued interest of $2.88, balance = 144.28
# 2026-09-01: Payment of $8, balance = 136.28
# 2026-10-01: Accrued interest of $2.69, balance = 138.97
# 2026-10-01: Payment of $8, balance = 130.97
# 2026-11-01: Accrued interest of $2.67, balance = 133.64
# 2026-11-01: Payment of $8, balance = 125.64
# 2026-12-01: Accrued interest of $2.48, balance = 128.12
# 2026-12-01: Payment of $8, balance = 120.12
# 2027-01-01: Accrued interest of $2.45, balance = 122.57
# 2027-01-01: Payment of $8, balance = 114.57
# 2027-02-01: Accrued interest of $2.34, balance = 116.91
# 2027-02-01: Payment of $8, balance = 108.91
# 2027-03-01: Accrued interest of $2.01, balance = 110.92
# 2027-03-01: Payment of $8, balance = 102.92
# 2027-04-01: Accrued interest of $2.1, balance = 105.02
# 2027-04-01: Payment of $8, balance = 97.02
# 2027-05-01: Accrued interest of $1.91, balance = 98.93
# 2027-05-01: Payment of $8, balance = 90.93
# 2027-06-01: Accrued interest of $1.85, balance = 92.78
# 2027-06-01: Payment of $8, balance = 84.78
# 2027-07-01: Accrued interest of $1.67, balance = 86.45
# 2027-07-01: Payment of $8, balance = 78.45
# 2027-08-01: Accrued interest of $1.6, balance = 80.05
# 2027-08-01: Payment of $8, balance = 72.05
# 2027-09-01: Accrued interest of $1.47, balance = 73.52
# 2027-09-01: Payment of $8, balance = 65.52
# 2027-10-01: Accrued interest of $1.29, balance = 66.81
# 2027-10-01: Payment of $8, balance = 58.81
# 2027-11-01: Accrued interest of $1.2, balance = 60.01
# 2027-11-01: Payment of $8, balance = 52.01
# 2027-12-01: Accrued interest of $1.03, balance = 53.04
# 2027-12-01: Payment of $8, balance = 45.04
# 2028-01-01: Accrued interest of $0.92, balance = 45.96
# 2028-01-01: Payment of $8, balance = 37.96
# 2028-02-01: Accrued interest of $0.77, balance = 38.73
# 2028-02-01: Payment of $8, balance = 30.73
# 2028-03-01: Accrued interest of $0.59, balance = 31.32
# 2028-03-01: Payment of $8, balance = 23.32
# 2028-04-01: Accrued interest of $0.48, balance = 23.8
# 2028-04-01: Payment of $8, balance = 15.8
# 2028-05-01: Accrued interest of $0.31, balance = 16.11
# 2028-05-01: Payment of $8, balance = 8.11
# 2028-06-01: Accrued interest of $0.17, balance = 8.28
# 2028-06-01: Payment of $8, balance = 0.28
# 2028-07-01: Accrued interest of $0.01, balance = 0.29
# 2028-07-01: Payment of $0.29, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-11-01: Accrued interest of $3.99, balance = 199.86
# 2025-11-01: Payment of $8, balance = 191.86
# 2025-12-01: Accrued interest of $3.78, balance = 195.64
# 2025-12-01: Payment of $8, balance = 187.64
# 2026-01-01: Accrued interest of $3.82, balance = 191.46
# 2026-01-01: Payment of $8, balance = 183.46
# 2026-02-01: Accrued interest of $3.74, balance = 187.2
# 2026-03-01: Accrued interest of $3.45, balance = 190.65
# 2026-03-01: Payment of $8, balance = 182.65
# 2026-04-01: Accrued interest of $3.72, balance = 186.37
# 2026-04-01: Payment of $8, balance = 178.37
# 2026-05-01: Accrued interest of $3.52, balance = 181.89
# 2026-06-01: Accrued interest of $3.71, balance = 185.6
# 2026-06-01: Payment of $8, balance = 177.6
# 2026-07-01: Accrued interest of $3.5, balance = 181.1
# 2026-07-01: Payment of $8, balance = 173.1
# 2026-08-01: Accrued interest of $3.53, balance = 176.63
# 2026-08-01: Payment of $8, balance = 168.63
# 2026-09-01: Accrued interest of $3.44, balance = 172.07
# 2026-10-01: Accrued interest of $3.39, balance = 175.46
# 2026-11-01: Accrued interest of $3.58, balance = 179.04
# 2026-11-01: Payment of $8, balance = 171.04
# 2026-12-01: Accrued interest of $3.37, balance = 174.41
# 2026-12-01: Payment of $8, balance = 166.41
# 2027-01-01: Accrued interest of $3.39, balance = 169.8
# 2027-01-01: Payment of $8, balance = 161.8
# 2027-02-01: Accrued interest of $3.3, balance = 165.1
# 2027-02-01: Payment of $8, balance = 157.1
# 2027-03-01: Accrued interest of $2.89, balance = 159.99
# 2027-04-01: Accrued interest of $3.26, balance = 163.25
# 2027-04-01: Payment of $8, balance = 155.25
# 2027-05-01: Accrued interest of $3.06, balance = 158.31
# 2027-05-01: Payment of $8, balance = 150.31
# 2027-06-01: Accrued interest of $3.06, balance = 153.37
# 2027-06-01: Payment of $8, balance = 145.37
# 2027-07-01: Accrued interest of $2.87, balance = 148.24
# 2027-07-01: Payment of $8, balance = 140.24
# 2027-08-01: Accrued interest of $2.86, balance = 143.1
# 2027-09-01: Accrued interest of $2.92, balance = 146.02
# 2027-09-01: Payment of $8, balance = 138.02
# 2027-10-01: Accrued interest of $2.72, balance = 140.74
# 2027-11-01: Accrued interest of $2.87, balance = 143.61
# 2027-11-01: Payment of $8, balance = 135.61
# 2027-12-01: Accrued interest of $2.68, balance = 138.29
# 2027-12-01: Payment of $8, balance = 130.29
# 2028-01-01: Accrued interest of $2.66, balance = 132.95
# 2028-01-01: Payment of $8, balance = 124.95
# 2028-02-01: Accrued interest of $2.55, balance = 127.5
# 2028-02-01: Payment of $8, balance = 119.5
# 2028-03-01: Accrued interest of $2.28, balance = 121.78
# 2028-03-01: Payment of $8, balance = 113.78
# 2028-04-01: Accrued interest of $2.32, balance = 116.1
# 2028-04-01: Payment of $8, balance = 108.1
# 2028-05-01: Accrued interest of $2.13, balance = 110.23
# 2028-05-01: Payment of $8, balance = 102.23
# 2028-06-01: Accrued interest of $2.08, balance = 104.31
# 2028-06-01: Payment of $8, balance = 96.31
# 2028-07-01: Accrued interest of $1.9, balance = 98.21
# 2028-07-01: Payment of $8, balance = 90.21
# 2028-08-01: Accrued interest of $1.84, balance = 92.05
# 2028-08-01: Payment of $8, balance = 84.05
# 2028-09-01: Accrued interest of $1.71, balance = 85.76
# 2028-09-01: Payment of $8, balance = 77.76
# 2028-10-01: Accrued interest of $1.53, balance = 79.29
# 2028-10-01: Payment of $8, balance = 71.29
# 2028-11-01: Accrued interest of $1.45, balance = 72.74
# 2028-11-01: Payment of $8, balance = 64.74
# 2028-12-01: Accrued interest of $1.28, balance = 66.02
# 2028-12-01: Payment of $8, balance = 58.02
# 2029-01-01: Accrued interest of $1.18, balance = 59.2
# 2029-02-01: Accrued interest of $1.21, balance = 60.41
# 2029-03-01: Accrued interest of $1.11, balance = 61.52
# 2029-04-01: Accrued interest of $1.25, balance = 62.77
# 2029-05-01: Accrued interest of $1.24, balance = 64.01
# 2029-06-01: Accrued interest of $1.3, balance = 65.31
# 2029-06-01: Payment of $8, balance = 57.31
# 2029-07-01: Accrued interest of $1.13, balance = 58.44
# 2029-07-01: Payment of $8, balance = 50.44
# 2029-08-01: Accrued interest of $1.03, balance = 51.47
# 2029-08-01: Payment of $8, balance = 43.47
# 2029-09-01: Accrued interest of $0.89, balance = 44.36
# 2029-09-01: Payment of $8, balance = 36.36
# 2029-10-01: Accrued interest of $0.72, balance = 37.08
# 2029-11-01: Accrued interest of $0.76, balance = 37.84
# 2029-12-01: Accrued interest of $0.75, balance = 38.59
# 2030-01-01: Accrued interest of $0.79, balance = 39.38
# 2030-01-01: Payment of $8, balance = 31.38
# 2030-02-01: Accrued interest of $0.64, balance = 32.02
# 2030-03-01: Accrued interest of $0.59, balance = 32.61
# 2030-03-01: Payment of $8, balance = 24.61
# 2030-04-01: Accrued interest of $0.5, balance = 25.11
# 2030-04-01: Payment of $8, balance = 17.11
# 2030-05-01: Accrued interest of $0.34, balance = 17.45
# 2030-05-01: Payment of $8, balance = 9.45
# 2030-06-01: Accrued interest of $0.19, balance = 9.64
# 2030-07-01: Accrued interest of $0.19, balance = 9.83
# 2030-08-01: Accrued interest of $0.2, balance = 10.03
# 2030-08-01: Payment of $8, balance = 2.03
# 2030-09-01: Accrued interest of $0.04, balance = 2.07
# 2030-09-01: Payment of $2.07, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-09-01: Accrued interest of $4.16, balance = 208.24
# 2025-09-01: Payment of $8, balance = 200.24
# 2025-10-01: Accrued interest of $3.95, balance = 204.19
# 2025-11-01: Accrued interest of $4.16, balance = 208.35
# 2025-12-01: Accrued interest of $4.11, balance = 212.46
# 2025-12-01: Payment of $8, balance = 204.46
# 2026-01-01: Accrued interest of $4.17, balance = 208.63
# 2026-02-01: Accrued interest of $4.25, balance = 212.88
# 2026-02-01: Payment of $8, balance = 204.88
# 2026-03-01: Accrued interest of $3.77, balance = 208.65
# 2026-03-01: Payment of $8, balance = 200.65
# 2026-04-01: Accrued interest of $4.09, balance = 204.74
# 2026-05-01: Accrued interest of $4.04, balance = 208.78
# 2026-05-01: Payment of $8, balance = 200.78
# 2026-06-01: Accrued interest of $4.09, balance = 204.87
# 2026-07-01: Accrued interest of $4.04, balance = 208.91
# 2026-07-01: Payment of $8, balance = 200.91
# 2026-08-01: Accrued interest of $4.1, balance = 205.01
# 2026-08-01: Payment of $8, balance = 197.01
# 2026-09-01: Accrued interest of $4.02, balance = 201.03
# 2026-10-01: Accrued interest of $3.97, balance = 205.0
# 2026-10-01: Payment of $8, balance = 197.0
# 2026-11-01: Accrued interest of $4.02, balance = 201.02
# 2026-12-01: Accrued interest of $3.97, balance = 204.99
# 2027-01-01: Accrued interest of $4.18, balance = 209.17
# 2027-02-01: Accrued interest of $4.26, balance = 213.43
# 2027-03-01: Accrued interest of $3.93, balance = 217.36
# 2027-03-01: Payment of $8, balance = 209.36
# 2027-04-01: Accrued interest of $4.27, balance = 213.63
# 2027-05-01: Accrued interest of $4.21, balance = 217.84
# 2027-06-01: Accrued interest of $4.44, balance = 222.28
# 2027-07-01: Accrued interest of $4.38, balance = 226.66
# 2027-07-01: Payment of $8, balance = 218.66
# 2027-08-01: Accrued interest of $4.46, balance = 223.12
# 2027-08-01: Payment of $8, balance = 215.12
# 2027-09-01: Accrued interest of $4.38, balance = 219.5
# 2027-10-01: Accrued interest of $4.33, balance = 223.83
# 2027-10-01: Payment of $8, balance = 215.83
# 2027-11-01: Accrued interest of $4.4, balance = 220.23
# 2027-11-01: Payment of $8, balance = 212.23
# 2027-12-01: Accrued interest of $4.19, balance = 216.42
# 2028-01-01: Accrued interest of $4.41, balance = 220.83
# 2028-01-01: Payment of $8, balance = 212.83
# 2028-02-01: Accrued interest of $4.34, balance = 217.17
# 2028-02-01: Payment of $8, balance = 209.17
# 2028-03-01: Accrued interest of $3.99, balance = 213.16
# 2028-03-01: Payment of $8, balance = 205.16
# 2028-04-01: Accrued interest of $4.18, balance = 209.34
# 2028-05-01: Accrued interest of $4.13, balance = 213.47
# 2028-06-01: Accrued interest of $4.35, balance = 217.82
# 2028-06-01: Payment of $8, balance = 209.82
# 2028-07-01: Accrued interest of $4.14, balance = 213.96
# 2028-07-01: Payment of $8, balance = 205.96
# 2028-08-01: Accrued interest of $4.2, balance = 210.16
# 2028-08-01: Payment of $8, balance = 202.16
# 2028-09-01: Accrued interest of $4.12, balance = 206.28
# 2028-09-01: Payment of $8, balance = 198.28
# 2028-10-01: Accrued interest of $3.91, balance = 202.19
# 2028-10-01: Payment of $8, balance = 194.19
# 2028-11-01: Accrued interest of $3.96, balance = 198.15
# 2028-12-01: Accrued interest of $3.91, balance = 202.06
# 2028-12-01: Payment of $8, balance = 194.06
# 2029-01-01: Accrued interest of $3.96, balance = 198.02
# 2029-01-01: Payment of $8, balance = 190.02
# 2029-02-01: Accrued interest of $3.87, balance = 193.89
# 2029-03-01: Accrued interest of $3.57, balance = 197.46
# 2029-03-01: Payment of $8, balance = 189.46
# 2029-04-01: Accrued interest of $3.86, balance = 193.32
# 2029-04-01: Payment of $8, balance = 185.32
# 2029-05-01: Accrued interest of $3.66, balance = 188.98
# 2029-06-01: Accrued interest of $3.85, balance = 192.83
# 2029-06-01: Payment of $8, balance = 184.83
# 2029-07-01: Accrued interest of $3.65, balance = 188.48
# 2029-07-01: Payment of $8, balance = 180.48
# 2029-08-01: Accrued interest of $3.68, balance = 184.16
# 2029-09-01: Accrued interest of $3.75, balance = 187.91
# 2029-10-01: Accrued interest of $3.71, balance = 191.62
# 2029-11-01: Accrued interest of $3.91, balance = 195.53
# 2029-11-01: Payment of $8, balance = 187.53
# 2029-12-01: Accrued interest of $3.7, balance = 191.23
# 2030-01-01: Accrued interest of $3.9, balance = 195.13
# 2030-02-01: Accrued interest of $3.98, balance = 199.11
# 2030-02-01: Payment of $8, balance = 191.11
# 2030-03-01: Accrued interest of $3.52, balance = 194.63
# 2030-04-01: Accrued interest of $3.97, balance = 198.6
# 2030-05-01: Accrued interest of $3.92, balance = 202.52
# 2030-05-01: Payment of $8, balance = 194.52
# 2030-06-01: Accrued interest of $3.97, balance = 198.49
# 2030-06-01: Payment of $8, balance = 190.49
# 2030-07-01: Accrued interest of $3.76, balance = 194.25
# 2030-08-01: Accrued interest of $3.96, balance = 198.21
# 2030-08-01: Payment of $8, balance = 190.21
# 2030-09-01: Accrued interest of $3.88, balance = 194.09
# 2030-09-01: Payment of $8, balance = 186.09
# 2030-10-01: Accrued interest of $3.67, balance = 189.76
# 2030-10-01: Payment of $8, balance = 181.76
# 2030-11-01: Accrued interest of $3.7, balance = 185.46
# 2030-11-01: Payment of $8, balance = 177.46
# 2030-12-01: Accrued interest of $3.5, balance = 180.96
# 2031-01-01: Accrued interest of $3.69, balance = 184.65
# 2031-02-01: Accrued interest of $3.76, balance = 188.41
# 2031-02-01: Payment of $8, balance = 180.41
# 2031-03-01: Accrued interest of $3.32, balance = 183.73
# 2031-03-01: Payment of $8, balance = 175.73
# 2031-04-01: Accrued interest of $3.58, balance = 179.31
# 2031-05-01: Accrued interest of $3.54, balance = 182.85
# 2031-05-01: Payment of $8, balance = 174.85
# 2031-06-01: Accrued interest of $3.56, balance = 178.41
# 2031-07-01: Accrued interest of $3.52, balance = 181.93
# 2031-07-01: Payment of $8, balance = 173.93
# 2031-08-01: Accrued interest of $3.55, balance = 177.48
# 2031-09-01: Accrued interest of $3.62, balance = 181.1
# 2031-09-01: Payment of $8, balance = 173.1
# 2031-10-01: Accrued interest of $3.41, balance = 176.51
# 2031-10-01: Payment of $8, balance = 168.51
# 2031-11-01: Accrued interest of $3.43, balance = 171.94
# 2031-11-01: Payment of $8, balance = 163.94
# 2031-12-01: Accrued interest of $3.23, balance = 167.17
# 2031-12-01: Payment of $8, balance = 159.17
# 2032-01-01: Accrued interest of $3.24, balance = 162.41
# 2032-02-01: Accrued interest of $3.31, balance = 165.72
# 2032-02-01: Payment of $8, balance = 157.72
# 2032-03-01: Accrued interest of $3.01, balance = 160.73
# 2032-03-01: Payment of $8, balance = 152.73
# 2032-04-01: Accrued interest of $3.11, balance = 155.84
# 2032-04-01: Payment of $8, balance = 147.84
# 2032-05-01: Accrued interest of $2.92, balance = 150.76
# 2032-06-01: Accrued interest of $3.07, balance = 153.83
# 2032-07-01: Accrued interest of $3.03, balance = 156.86
# 2032-08-01: Accrued interest of $3.2, balance = 160.06
# 2032-09-01: Accrued interest of $3.26, balance = 163.32
# 2032-09-01: Payment of $8, balance = 155.32
# 2032-10-01: Accrued interest of $3.06, balance = 158.38
# 2032-10-01: Payment of $8, balance = 150.38
# 2032-11-01: Accrued interest of $3.07, balance = 153.45
# 2032-12-01: Accrued interest of $3.03, balance = 156.48
# 2032-12-01: Payment of $8, balance = 148.48
# 2033-01-01: Accrued interest of $3.03, balance = 151.51
# 2033-01-01: Payment of $8, balance = 143.51
# 2033-02-01: Accrued interest of $2.93, balance = 146.44
# 2033-02-01: Payment of $8, balance = 138.44
# 2033-03-01: Accrued interest of $2.55, balance = 140.99
# 2033-03-01: Payment of $8, balance = 132.99
# 2033-04-01: Accrued interest of $2.71, balance = 135.7
# 2033-05-01: Accrued interest of $2.68, balance = 138.38
# 2033-05-01: Payment of $8, balance = 130.38
# 2033-06-01: Accrued interest of $2.66, balance = 133.04
# 2033-07-01: Accrued interest of $2.62, balance = 135.66
# 2033-08-01: Accrued interest of $2.77, balance = 138.43
# 2033-08-01: Payment of $8, balance = 130.43
# 2033-09-01: Accrued interest of $2.66, balance = 133.09
# 2033-09-01: Payment of $8, balance = 125.09
# 2033-10-01: Accrued interest of $2.47, balance = 127.56
# 2033-11-01: Accrued interest of $2.6, balance = 130.16
# 2033-11-01: Payment of $8, balance = 122.16
# 2033-12-01: Accrued interest of $2.41, balance = 124.57
# 2034-01-01: Accrued interest of $2.54, balance = 127.11
# 2034-01-01: Payment of $8, balance = 119.11
# 2034-02-01: Accrued interest of $2.43, balance = 121.54
# 2034-02-01: Payment of $8, balance = 113.54
# 2034-03-01: Accrued interest of $2.09, balance = 115.63
# 2034-03-01: Payment of $8, balance = 107.63
# 2034-04-01: Accrued interest of $2.19, balance = 109.82
# 2034-04-01: Payment of $8, balance = 101.82
# 2034-05-01: Accrued interest of $2.01, balance = 103.83
# 2034-06-01: Accrued interest of $2.12, balance = 105.95
# 2034-06-01: Payment of $8, balance = 97.95
# 2034-07-01: Accrued interest of $1.93, balance = 99.88
# 2034-08-01: Accrued interest of $2.04, balance = 101.92
# 2034-09-01: Accrued interest of $2.08, balance = 104.0
# 2034-10-01: Accrued interest of $2.05, balance = 106.05
# 2034-10-01: Payment of $8, balance = 98.05
# 2034-11-01: Accrued interest of $2.0, balance = 100.05
# 2034-11-01: Payment of $8, balance = 92.05
# 2034-12-01: Accrued interest of $1.82, balance = 93.87
# 2034-12-01: Payment of $8, balance = 85.87
# 2035-01-01: Accrued interest of $1.75, balance = 87.62
# 2035-02-01: Accrued interest of $1.79, balance = 89.41
# 2035-03-01: Accrued interest of $1.65, balance = 91.06
# 2035-04-01: Accrued interest of $1.86, balance = 92.92
# 2035-04-01: Payment of $8, balance = 84.92
# 2035-05-01: Accrued interest of $1.68, balance = 86.6
# 2035-06-01: Accrued interest of $1.77, balance = 88.37
# 2035-07-01: Accrued interest of $1.74, balance = 90.11
# 2035-07-01: Payment of $8, balance = 82.11
# 2035-08-01: Accrued interest of $1.67, balance = 83.78
# 2035-09-01: Accrued interest of $1.71, balance = 85.49
# 2035-10-01: Accrued interest of $1.69, balance = 87.18
# 2035-10-01: Payment of $8, balance = 79.18
# 2035-11-01: Accrued interest of $1.61, balance = 80.79
# 2035-12-01: Accrued interest of $1.59, balance = 82.38
# 2035-12-01: Payment of $8, balance = 74.38
# 2036-01-01: Accrued interest of $1.52, balance = 75.9
# 2036-01-01: Payment of $8, balance = 67.9
# 2036-02-01: Accrued interest of $1.38, balance = 69.28
# 2036-03-01: Accrued interest of $1.32, balance = 70.6
# 2036-03-01: Payment of $8, balance = 62.6
# 2036-04-01: Accrued interest of $1.28, balance = 63.88
# 2036-05-01: Accrued interest of $1.26, balance = 65.14
# 2036-06-01: Accrued interest of $1.33, balance = 66.47
# 2036-06-01: Payment of $8, balance = 58.47
# 2036-07-01: Accrued interest of $1.15, balance = 59.62
# 2036-07-01: Payment of $8, balance = 51.62
# 2036-08-01: Accrued interest of $1.05, balance = 52.67
# 2036-09-01: Accrued interest of $1.07, balance = 53.74
# 2036-10-01: Accrued interest of $1.06, balance = 54.8
# 2036-10-01: Payment of $8, balance = 46.8
# 2036-11-01: Accrued interest of $0.95, balance = 47.75
# 2036-12-01: Accrued interest of $0.94, balance = 48.69
# 2036-12-01: Payment of $8, balance = 40.69
# 2037-01-01: Accrued interest of $0.83, balance = 41.52
# 2037-02-01: Accrued interest of $0.85, balance = 42.37
# 2037-02-01: Payment of $8, balance = 34.37
# 2037-03-01: Accrued interest of $0.63, balance = 35.0
# 2037-03-01: Payment of $8, balance = 27.0
# 2037-04-01: Accrued interest of $0.55, balance = 27.55
# 2037-04-01: Payment of $8, balance = 19.55
# 2037-05-01: Accrued interest of $0.39, balance = 19.94
# 2037-05-01: Payment of $8, balance = 11.94
# 2037-06-01: Accrued interest of $0.24, balance = 12.18
# 2037-07-01: Accrued interest of $0.24, balance = 12.42
# 2037-08-01: Accrued interest of $0.25, balance = 12.67
# 2037-08-01: Payment of $8, balance = 4.67
# 2037-09-01: Accrued interest of $0.1, balance = 4.77
# 2037-10-01: Accrued interest of $0.09, balance = 4.86
# 2037-11-01: Accrued interest of $0.1, balance = 4.96
# 2037-11-01: Payment of $4.96, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-10-01: Payment of $8, balance = 187.87
# 2025-11-01: Accrued interest of $3.83, balance = 191.7
# 2025-11-01: Payment of $8, balance = 183.7
# 2025-12-01: Accrued interest of $3.62, balance = 187.32
# 2025-12-01: Payment of $8, balance = 179.32
# 2026-01-01: Accrued interest of $3.66, balance = 182.98
# 2026-01-01: Payment of $8, balance = 174.98
# 2026-02-01: Accrued interest of $3.57, balance = 178.55
# 2026-02-01: Payment of $8, balance = 170.55
# 2026-03-01: Accrued interest of $3.14, balance = 173.69
# 2026-03-01: Payment of $8, balance = 165.69
# 2026-04-01: Accrued interest of $3.38, balance = 169.07
# 2026-04-01: Payment of $8, balance = 161.07
# 2026-05-01: Accrued interest of $3.18, balance = 164.25
# 2026-05-01: Payment of $8, balance = 156.25
# 2026-06-01: Accrued interest of $3.18, balance = 159.43
# 2026-06-01: Payment of $8, balance = 151.43
# 2026-07-01: Accrued interest of $2.99, balance = 154.42
# 2026-07-01: Payment of $8, balance = 146.42
# 2026-08-01: Accrued interest of $2.98, balance = 149.4
# 2026-08-01: Payment of $8, balance = 141.4
# 2026-09-01: Accrued interest of $2.88, balance = 144.28
# 2026-09-01: Payment of $8, balance = 136.28
# 2026-10-01: Accrued interest of $2.69, balance = 138.97
# 2026-10-01: Payment of $8, balance = 130.97
# 2026-11-01: Accrued interest of $2.67, balance = 133.64
# 2026-11-01: Payment of $8, balance = 125.64
# 2026-12-01: Accrued interest of $2.48, balance = 128.12
# 2026-12-01: Payment of $8, balance = 120.12
# 2027-01-01: Accrued interest of $2.45, balance = 122.57
# 2027-01-01: Payment of $8, balance = 114.57
# 2027-02-01: Accrued interest of $2.34, balance = 116.91
# 2027-02-01: Payment of $8, balance = 108.91
# 2027-03-01: Accrued interest of $2.01, balance = 110.92
# 2027-03-01: Payment of $8, balance = 102.92
# 2027-04-01: Accrued interest of $2.1, balance = 105.02
# 2027-04-01: Payment of $8, balance = 97.02
# 2027-05-01: Accrued interest of $1.91, balance = 98.93
# 2027-05-01: Payment of $8, balance = 90.93
# 2027-06-01: Accrued interest of $1.85, balance = 92.78
# 2027-06-01: Payment of $8, balance = 84.78
# 2027-07-01: Accrued interest of $1.67, balance = 86.45
# 2027-07-01: Payment of $8, balance = 78.45
# 2027-08-01: Accrued interest of $1.6, balance = 80.05
# 2027-08-01: Payment of $8, balance = 72.05
# 2027-09-01: Accrued interest of $1.47, balance = 73.52
# 2027-09-01: Payment of $8, balance = 65.52
# 2027-10-01: Accrued interest of $1.29, balance = 66.81
# 2027-10-01: Payment of $8, balance = 58.81
# 2027-11-01: Accrued interest of $1.2, balance = 60.01
# 2027-11-01: Payment of $8, balance = 52.01
# 2027-12-01: Accrued interest of $1.03, balance = 53.04
# 2027-12-01: Payment of $8, balance = 45.04
# 2028-01-01: Accrued interest of $0.92, balance = 45.96
# 2028-01-01: Payment of $8, balance = 37.96
# 2028-02-01: Accrued interest of $0.77, balance = 38.73
# 2028-02-01: Payment of $8, balance = 30.73
# 2028-03-01: Accrued interest of $0.59, balance = 31.32
# 2028-03-01: Payment of $8, balance = 23.32
# 2028-04-01: Accrued interest of $0.48, balance = 23.8
# 2028-04-01: Payment of $8, balance = 15.8
# 2028-05-01: Accrued interest of $0.31, balance = 16.11
# 2028-05-01: Payment of $8, balance = 8.11
# 2028-06-01: Accrued interest of $0.17, balance = 8.28
# 2028-06-01: Payment of $8, balance = 0.28
# 2028-07-01: Accrued interest of $0.01, balance = 0.29
# 2028-07-01: Payment of $0.29, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-10-01: Payment of $8, balance = 187.87
# 2025-11-01: Accrued interest of $3.83, balance = 191.7
# 2025-11-01: Payment of $8, balance = 183.7
# 2025-12-01: Accrued interest of $3.62, balance = 187.32
# 2025-12-01: Payment of $8, balance = 179.32
# 2026-01-01: Accrued interest of $3.66, balance = 182.98
# 2026-01-01: Payment of $8, balance = 174.98
# 2026-02-01: Accrued interest of $3.57, balance = 178.55
# 2026-02-01: Payment of $8, balance = 170.55
# 2026-03-01: Accrued interest of $3.14, balance = 173.69
# 2026-03-01: Payment of $8, balance = 165.69
# 2026-04-01: Accrued interest of $3.38, balance = 169.07
# 2026-05-01: Accrued interest of $3.34, balance = 172.41
# 2026-05-01: Payment of $8, balance = 164.41
# 2026-06-01: Accrued interest of $3.35, balance = 167.76
# 2026-07-01: Accrued interest of $3.31, balance = 171.07
# 2026-08-01: Accrued interest of $3.49, balance = 174.56
# 2026-08-01: Payment of $8, balance = 166.56
# 2026-09-01: Accrued interest of $3.4, balance = 169.96
# 2026-09-01: Payment of $8, balance = 161.96
# 2026-10-01: Accrued interest of $3.19, balance = 165.15
# 2026-10-01: Payment of $8, balance = 157.15
# 2026-11-01: Accrued interest of $3.2, balance = 160.35
# 2026-11-01: Payment of $8, balance = 152.35
# 2026-12-01: Accrued interest of $3.01, balance = 155.36
# 2026-12-01: Payment of $8, balance = 147.36
# 2027-01-01: Accrued interest of $3.0, balance = 150.36
# 2027-01-01: Payment of $8, balance = 142.36
# 2027-02-01: Accrued interest of $2.9, balance = 145.26
# 2027-03-01: Accrued interest of $2.67, balance = 147.93
# 2027-04-01: Accrued interest of $3.02, balance = 150.95
# 2027-04-01: Payment of $8, balance = 142.95
# 2027-05-01: Accrued interest of $2.82, balance = 145.77
# 2027-05-01: Payment of $8, balance = 137.77
# 2027-06-01: Accrued interest of $2.81, balance = 140.58
# 2027-07-01: Accrued interest of $2.77, balance = 143.35
# 2027-07-01: Payment of $8, balance = 135.35
# 2027-08-01: Accrued interest of $2.76, balance = 138.11
# 2027-08-01: Payment of $8, balance = 130.11
# 2027-09-01: Accrued interest of $2.65, balance = 132.76
# 2027-09-01: Payment of $8, balance = 124.76
# 2027-10-01: Accrued interest of $2.46, balance = 127.22
# 2027-10-01: Payment of $8, balance = 119.22
# 2027-11-01: Accrued interest of $2.43, balance = 121.65
# 2027-11-01: Payment of $8, balance = 113.65
# 2027-12-01: Accrued interest of $2.24, balance = 115.89
# 2027-12-01: Payment of $8, balance = 107.89
# 2028-01-01: Accrued interest of $2.2, balance = 110.09
# 2028-01-01: Payment of $8, balance = 102.09
# 2028-02-01: Accrued interest of $2.08, balance = 104.17
# 2028-02-01: Payment of $8, balance = 96.17
# 2028-03-01: Accrued interest of $1.83, balance = 98.0
# 2028-03-01: Payment of $8, balance = 90.0
# 2028-04-01: Accrued interest of $1.83, balance = 91.83
# 2028-04-01: Payment of $8, balance = 83.83
# 2028-05-01: Accrued interest of $1.65, balance = 85.48
# 2028-05-01: Payment of $8, balance = 77.48
# 2028-06-01: Accrued interest of $1.58, balance = 79.06
# 2028-06-01: Payment of $8, balance = 71.06
# 2028-07-01: Accrued interest of $1.4, balance = 72.46
# 2028-07-01: Payment of $8, balance = 64.46
# 2028-08-01: Accrued interest of $1.31, balance = 65.77
# 2028-08-01: Payment of $8, balance = 57.77
# 2028-09-01: Accrued interest of $1.18, balance = 58.95
# 2028-10-01: Accrued interest of $1.16, balance = 60.11
# 2028-10-01: Payment of $8, balance = 52.11
# 2028-11-01: Accrued interest of $1.06, balance = 53.17
# 2028-11-01: Payment of $8, balance = 45.17
# 2028-12-01: Accrued interest of $0.89, balance = 46.06
# 2028-12-01: Payment of $8, balance = 38.06
# 2029-01-01: Accrued interest of $0.78, balance = 38.84
# 2029-01-01: Payment of $8, balance = 30.84
# 2029-02-01: Accrued interest of $0.63, balance = 31.47
# 2029-02-01: Payment of $8, balance = 23.47
# 2029-03-01: Accrued interest of $0.43, balance = 23.9
# 2029-04-01: Accrued interest of $0.49, balance = 24.39
# 2029-04-01: Payment of $8, balance = 16.39
# 2029-05-01: Accrued interest of $0.32, balance = 16.71
# 2029-06-01: Accrued interest of $0.34, balance = 17.05
# 2029-06-01: Payment of $8, balance = 9.05
# 2029-07-01: Accrued interest of $0.18, balance = 9.23
# 2029-07-01: Payment of $8, balance = 1.23
# 2029-08-01: Accrued interest of $0.03, balance = 1.26
# 2029-08-01: Payment of $1.26, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-10-01: Payment of $8, balance = 187.87
# 2025-11-01: Accrued interest of $3.83, balance = 191.7
# 2025-12-01: Accrued interest of $3.78, balance = 195.48
# 2025-12-01: Payment of $8, balance = 187.48
# 2026-01-01: Accrued interest of $3.82, balance = 191.3
# 2026-01-01: Payment of $8, balance = 183.3
# 2026-02-01: Accrued interest of $3.74, balance = 187.04
# 2026-02-01: Payment of $8, balance = 179.04
# 2026-03-01: Accrued interest of $3.3, balance = 182.34
# 2026-03-01: Payment of $8, balance = 174.34
# 2026-04-01: Accrued interest of $3.55, balance = 177.89
# 2026-05-01: Accrued interest of $3.51, balance = 181.4
# 2026-05-01: Payment of $8, balance = 173.4
# 2026-06-01: Accrued interest of $3.53, balance = 176.93
# 2026-07-01: Accrued interest of $3.49, balance = 180.42
# 2026-08-01: Accrued interest of $3.68, balance = 184.1
# 2026-08-01: Payment of $8, balance = 176.1
# 2026-09-01: Accrued interest of $3.59, balance = 179.69
# 2026-09-01: Payment of $8, balance = 171.69
# 2026-10-01: Accrued interest of $3.39, balance = 175.08
# 2026-11-01: Accrued interest of $3.57, balance = 178.65
# 2026-12-01: Accrued interest of $3.52, balance = 182.17
# 2026-12-01: Payment of $8, balance = 174.17
# 2027-01-01: Accrued interest of $3.55, balance = 177.72
# 2027-02-01: Accrued interest of $3.62, balance = 181.34
# 2027-02-01: Payment of $8, balance = 173.34
# 2027-03-01: Accrued interest of $3.19, balance = 176.53
# 2027-03-01: Payment of $8, balance = 168.53
# 2027-04-01: Accrued interest of $3.44, balance = 171.97
# 2027-04-01: Payment of $8, balance = 163.97
# 2027-05-01: Accrued interest of $3.23, balance = 167.2
# 2027-06-01: Accrued interest of $3.41, balance = 170.61
# 2027-06-01: Payment of $8, balance = 162.61
# 2027-07-01: Accrued interest of $3.21, balance = 165.82
# 2027-08-01: Accrued interest of $3.38, balance = 169.2
# 2027-08-01: Payment of $8, balance = 161.2
# 2027-09-01: Accrued interest of $3.29, balance = 164.49
# 2027-09-01: Payment of $8, balance = 156.49
# 2027-10-01: Accrued interest of $3.09, balance = 159.58
# 2027-11-01: Accrued interest of $3.25, balance = 162.83
# 2027-12-01: Accrued interest of $3.21, balance = 166.04
# 2028-01-01: Accrued interest of $3.38, balance = 169.42
# 2028-01-01: Payment of $8, balance = 161.42
# 2028-02-01: Accrued interest of $3.29, balance = 164.71
# 2028-02-01: Payment of $8, balance = 156.71
# 2028-03-01: Accrued interest of $2.99, balance = 159.7
# 2028-03-01: Payment of $8, balance = 151.7
# 2028-04-01: Accrued interest of $3.09, balance = 154.79
# 2028-05-01: Accrued interest of $3.05, balance = 157.84
# 2028-06-01: Accrued interest of $3.22, balance = 161.06
# 2028-07-01: Accrued interest of $3.18, balance = 164.24
# 2028-08-01: Accrued interest of $3.35, balance = 167.59
# 2028-09-01: Accrued interest of $3.42, balance = 171.01
# 2028-09-01: Payment of $8, balance = 163.01
# 2028-10-01: Accrued interest of $3.22, balance = 166.23
# 2028-10-01: Payment of $8, balance = 158.23
# 2028-11-01: Accrued interest of $3.23, balance = 161.46
# 2028-12-01: Accrued interest of $3.18, balance = 164.64
# 2028-12-01: Payment of $8, balance = 156.64
# 2029-01-01: Accrued interest of $3.19, balance = 159.83
# 2029-01-01: Payment of $8, balance = 151.83
# 2029-02-01: Accrued interest of $3.09, balance = 154.92
# 2029-02-01: Payment of $8, balance = 146.92
# 2029-03-01: Accrued interest of $2.7, balance = 149.62
# 2029-03-01: Payment of $8, balance = 141.62
# 2029-04-01: Accrued interest of $2.89, balance = 144.51
# 2029-05-01: Accrued interest of $2.85, balance = 147.36
# 2029-05-01: Payment of $8, balance = 139.36
# 2029-06-01: Accrued interest of $2.84, balance = 142.2
# 2029-06-01: Payment of $8, balance = 134.2
# 2029-07-01: Accrued interest of $2.65, balance = 136.85
# 2029-07-01: Payment of $8, balance = 128.85
# 2029-08-01: Accrued interest of $2.63, balance = 131.48
# 2029-09-01: Accrued interest of $2.68, balance = 134.16
# 2029-10-01: Accrued interest of $2.65, balance = 136.81
# 2029-11-01: Accrued interest of $2.79, balance = 139.6
# 2029-12-01: Accrued interest of $2.75, balance = 142.35
# 2030-01-01: Accrued interest of $2.9, balance = 145.25
# 2030-02-01: Accrued interest of $2.96, balance = 148.21
# 2030-03-01: Accrued interest of $2.73, balance = 150.94
# 2030-04-01: Accrued interest of $3.08, balance = 154.02
# 2030-05-01: Accrued interest of $3.04, balance = 157.06
# 2030-06-01: Accrued interest of $3.2, balance = 160.26
# 2030-07-01: Accrued interest of $3.16, balance = 163.42
# 2030-08-01: Accrued interest of $3.33, balance = 166.75
# 2030-08-01: Payment of $8, balance = 158.75
# 2030-09-01: Accrued interest of $3.24, balance = 161.99
# 2030-10-01: Accrued interest of $3.2, balance = 165.19
# 2030-11-01: Accrued interest of $3.37, balance = 168.56
# 2030-12-01: Accrued interest of $3.33, balance = 171.89
# 2030-12-01: Payment of $8, balance = 163.89
# 2031-01-01: Accrued interest of $3.34, balance = 167.23
# 2031-02-01: Accrued interest of $3.41, balance = 170.64
# 2031-02-01: Payment of $8, balance = 162.64
# 2031-03-01: Accrued interest of $2.99, balance = 165.63
# 2031-04-01: Accrued interest of $3.38, balance = 169.01
# 2031-05-01: Accrued interest of $3.33, balance = 172.34
# 2031-06-01: Accrued interest of $3.51, balance = 175.85
# 2031-07-01: Accrued interest of $3.47, balance = 179.32
# 2031-07-01: Payment of $8, balance = 171.32
# 2031-08-01: Accrued interest of $3.49, balance = 174.81
# 2031-08-01: Payment of $8, balance = 166.81
# 2031-09-01: Accrued interest of $3.4, balance = 170.21
# 2031-10-01: Accrued interest of $3.36, balance = 173.57
# 2031-10-01: Payment of $8, balance = 165.57
# 2031-11-01: Accrued interest of $3.37, balance = 168.94
# 2031-11-01: Payment of $8, balance = 160.94
# 2031-12-01: Accrued interest of $3.17, balance = 164.11
# 2032-01-01: Accrued interest of $3.35, balance = 167.46
# 2032-02-01: Accrued interest of $3.41, balance = 170.87
# 2032-02-01: Payment of $8, balance = 162.87
# 2032-03-01: Accrued interest of $3.11, balance = 165.98
# 2032-03-01: Payment of $8, balance = 157.98
# 2032-04-01: Accrued interest of $3.22, balance = 161.2
# 2032-05-01: Accrued interest of $3.18, balance = 164.38
# 2032-05-01: Payment of $8, balance = 156.38
# 2032-06-01: Accrued interest of $3.19, balance = 159.57
# 2032-07-01: Accrued interest of $3.15, balance = 162.72
# 2032-07-01: Payment of $8, balance = 154.72
# 2032-08-01: Accrued interest of $3.15, balance = 157.87
# 2032-08-01: Payment of $8, balance = 149.87
# 2032-09-01: Accrued interest of $3.05, balance = 152.92
# 2032-10-01: Accrued interest of $3.02, balance = 155.94
# 2032-10-01: Payment of $8, balance = 147.94
# 2032-11-01: Accrued interest of $3.02, balance = 150.96
# 2032-11-01: Payment of $8, balance = 142.96
# 2032-12-01: Accrued interest of $2.82, balance = 145.78
# 2032-12-01: Payment of $8, balance = 137.78
# 2033-01-01: Accrued interest of $2.81, balance = 140.59
# 2033-01-01: Payment of $8, balance = 132.59
# 2033-02-01: Accrued interest of $2.7, balance = 135.29
# 2033-03-01: Accrued interest of $2.49, balance = 137.78
# 2033-04-01: Accrued interest of $2.81, balance = 140.59
# 2033-05-01: Accrued interest of $2.77, balance = 143.36
# 2033-05-01: Payment of $8, balance = 135.36
# 2033-06-01: Accrued interest of $2.76, balance = 138.12
# 2033-07-01: Accrued interest of $2.72, balance = 140.84
# 2033-07-01: Payment of $8, balance = 132.84
# 2033-08-01: Accrued interest of $2.71, balance = 135.55
# 2033-09-01: Accrued interest of $2.76, balance = 138.31
# 2033-09-01: Payment of $8, balance = 130.31
# 2033-10-01: Accrued interest of $2.57, balance = 132.88
# 2033-10-01: Payment of $8, balance = 124.88
# 2033-11-01: Accrued interest of $2.55, balance = 127.43
# 2033-11-01: Payment of $8, balance = 119.43
# 2033-12-01: Accrued interest of $2.36, balance = 121.79
# 2033-12-01: Payment of $8, balance = 113.79
# 2034-01-01: Accrued interest of $2.32, balance = 116.11
# 2034-01-01: Payment of $8, balance = 108.11
# 2034-02-01: Accrued interest of $2.2, balance = 110.31
# 2034-03-01: Accrued interest of $2.03, balance = 112.34
# 2034-04-01: Accrued interest of $2.29, balance = 114.63
# 2034-04-01: Payment of $8, balance = 106.63
# 2034-05-01: Accrued interest of $2.1, balance = 108.73
# 2034-06-01: Accrued interest of $2.22, balance = 110.95
# 2034-06-01: Payment of $8, balance = 102.95
# 2034-07-01: Accrued interest of $2.03, balance = 104.98
# 2034-07-01: Payment of $8, balance = 96.98
# 2034-08-01: Accrued interest of $1.98, balance = 98.96
# 2034-09-01: Accrued interest of $2.02, balance = 100.98
# 2034-09-01: Payment of $8, balance = 92.98
# 2034-10-01: Accrued interest of $1.83, balance = 94.81
# 2034-11-01: Accrued interest of $1.93, balance = 96.74
# 2034-12-01: Accrued interest of $1.91, balance = 98.65
# 2034-12-01: Payment of $8, balance = 90.65
# 2035-01-01: Accrued interest of $1.85, balance = 92.5
# 2035-02-01: Accrued interest of $1.89, balance = 94.39
# 2035-02-01: Payment of $8, balance = 86.39
# 2035-03-01: Accrued interest of $1.59, balance = 87.98
# 2035-03-01: Payment of $8, balance = 79.98
# 2035-04-01: Accrued interest of $1.63, balance = 81.61
# 2035-05-01: Accrued interest of $1.61, balance = 83.22
# 2035-06-01: Accrued interest of $1.7, balance = 84.92
# 2035-07-01: Accrued interest of $1.68, balance = 86.6
# 2035-07-01: Payment of $8, balance = 78.6
# 2035-08-01: Accrued interest of $1.6, balance = 80.2
# 2035-09-01: Accrued interest of $1.63, balance = 81.83
# 2035-10-01: Accrued interest of $1.61, balance = 83.44
# 2035-11-01: Accrued interest of $1.7, balance = 85.14
# 2035-12-01: Accrued interest of $1.68, balance = 86.82
# 2036-01-01: Accrued interest of $1.77, balance = 88.59
# 2036-02-01: Accrued interest of $1.81, balance = 90.4
# 2036-03-01: Accrued interest of $1.72, balance = 92.12
# 2036-04-01: Accrued interest of $1.88, balance = 94.0
# 2036-04-01: Payment of $8, balance = 86.0
# 2036-05-01: Accrued interest of $1.7, balance = 87.7
# 2036-06-01: Accrued interest of $1.79, balance = 89.49
# 2036-06-01: Payment of $8, balance = 81.49
# 2036-07-01: Accrued interest of $1.61, balance = 83.1
# 2036-08-01: Accrued interest of $1.69, balance = 84.79
# 2036-08-01: Payment of $8, balance = 76.79
# 2036-09-01: Accrued interest of $1.57, balance = 78.36
# 2036-10-01: Accrued interest of $1.55, balance = 79.91
# 2036-10-01: Payment of $8, balance = 71.91
# 2036-11-01: Accrued interest of $1.47, balance = 73.38
# 2036-11-01: Payment of $8, balance = 65.38
# 2036-12-01: Accrued interest of $1.29, balance = 66.67
# 2037-01-01: Accrued interest of $1.36, balance = 68.03
# 2037-01-01: Payment of $8, balance = 60.03
# 2037-02-01: Accrued interest of $1.22, balance = 61.25
# 2037-03-01: Accrued interest of $1.13, balance = 62.38
# 2037-04-01: Accrued interest of $1.27, balance = 63.65
# 2037-05-01: Accrued interest of $1.26, balance = 64.91
# 2037-06-01: Accrued interest of $1.32, balance = 66.23
# 2037-06-01: Payment of $8, balance = 58.23
# 2037-07-01: Accrued interest of $1.15, balance = 59.38
# 2037-07-01: Payment of $8, balance = 51.38
# 2037-08-01: Accrued interest of $1.05, balance = 52.43
# 2037-09-01: Accrued interest of $1.07, balance = 53.5
# 2037-10-01: Accrued interest of $1.06, balance = 54.56
# 2037-11-01: Accrued interest of $1.11, balance = 55.67
# 2037-12-01: Accrued interest of $1.1, balance = 56.77
# 2037-12-01: Payment of $8, balance = 48.77
# 2038-01-01: Accrued interest of $0.99, balance = 49.76
# 2038-01-01: Payment of $8, balance = 41.76
# 2038-02-01: Accrued interest of $0.85, balance = 42.61
# 2038-02-01: Payment of $8, balance = 34.61
# 2038-03-01: Accrued interest of $0.64, balance = 35.25
# 2038-03-01: Payment of $8, balance = 27.25
# 2038-04-01: Accrued interest of $0.56, balance = 27.81
# 2038-05-01: Accrued interest of $0.55, balance = 28.36
# 2038-06-01: Accrued interest of $0.58, balance = 28.94
# 2038-07-01: Accrued interest of $0.57, balance = 29.51
# 2038-07-01: Payment of $8, balance = 21.51
# 2038-08-01: Accrued interest of $0.44, balance = 21.95
# 2038-08-01: Payment of $8, balance = 13.95
# 2038-09-01: Accrued interest of $0.28, balance = 14.23
# 2038-10-01: Accrued interest of $0.28, balance = 14.51
# 2038-11-01: Accrued interest of $0.3, balance = 14.81
# 2038-11-01: Payment of $8, balance = 6.81
# 2038-12-01: Accrued interest of $0.13, balance = 6.94
# 2038-12-01: Payment of $6.94, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-10-01: Payment of $8, balance = 187.87
# 2025-11-01: Accrued interest of $3.83, balance = 191.7
# 2025-11-01: Payment of $8, balance = 183.7
# 2025-12-01: Accrued interest of $3.62, balance = 187.32
# 2025-12-01: Payment of $8, balance = 179.32
# 2026-01-01: Accrued interest of $3.66, balance = 182.98
# 2026-01-01: Payment of $8, balance = 174.98
# 2026-02-01: Accrued interest of $3.57, balance = 178.55
# 2026-02-01: Payment of $8, balance = 170.55
# 2026-03-01: Accrued interest of $3.14, balance = 173.69
# 2026-03-01: Payment of $8, balance = 165.69
# 2026-04-01: Accrued interest of $3.38, balance = 169.07
# 2026-04-01: Payment of $8, balance = 161.07
# 2026-05-01: Accrued interest of $3.18, balance = 164.25
# 2026-05-01: Payment of $8, balance = 156.25
# 2026-06-01: Accrued interest of $3.18, balance = 159.43
# 2026-06-01: Payment of $8, balance = 151.43
# 2026-07-01: Accrued interest of $2.99, balance = 154.42
# 2026-07-01: Payment of $8, balance = 146.42
# 2026-08-01: Accrued interest of $2.98, balance = 149.4
# 2026-08-01: Payment of $8, balance = 141.4
# 2026-09-01: Accrued interest of $2.88, balance = 144.28
# 2026-09-01: Payment of $8, balance = 136.28
# 2026-10-01: Accrued interest of $2.69, balance = 138.97
# 2026-10-01: Payment of $8, balance = 130.97
# 2026-11-01: Accrued interest of $2.67, balance = 133.64
# 2026-11-01: Payment of $8, balance = 125.64
# 2026-12-01: Accrued interest of $2.48, balance = 128.12
# 2026-12-01: Payment of $8, balance = 120.12
# 2027-01-01: Accrued interest of $2.45, balance = 122.57
# 2027-01-01: Payment of $8, balance = 114.57
# 2027-02-01: Accrued interest of $2.34, balance = 116.91
# 2027-02-01: Payment of $8, balance = 108.91
# 2027-03-01: Accrued interest of $2.01, balance = 110.92
# 2027-03-01: Payment of $8, balance = 102.92
# 2027-04-01: Accrued interest of $2.1, balance = 105.02
# 2027-04-01: Payment of $8, balance = 97.02
# 2027-05-01: Accrued interest of $1.91, balance = 98.93
# 2027-05-01: Payment of $8, balance = 90.93
# 2027-06-01: Accrued interest of $1.85, balance = 92.78
# 2027-06-01: Payment of $8, balance = 84.78
# 2027-07-01: Accrued interest of $1.67, balance = 86.45
# 2027-07-01: Payment of $8, balance = 78.45
# 2027-08-01: Accrued interest of $1.6, balance = 80.05
# 2027-08-01: Payment of $8, balance = 72.05
# 2027-09-01: Accrued interest of $1.47, balance = 73.52
# 2027-09-01: Payment of $8, balance = 65.52
# 2027-10-01: Accrued interest of $1.29, balance = 66.81
# 2027-10-01: Payment of $8, balance = 58.81
# 2027-11-01: Accrued interest of $1.2, balance = 60.01
# 2027-11-01: Payment of $8, balance = 52.01
# 2027-12-01: Accrued interest of $1.03, balance = 53.04
# 2027-12-01: Payment of $8, balance = 45.04
# 2028-01-01: Accrued interest of $0.92, balance = 45.96
# 2028-01-01: Payment of $8, balance = 37.96
# 2028-02-01: Accrued interest of $0.77, balance = 38.73
# 2028-02-01: Payment of $8, balance = 30.73
# 2028-03-01: Accrued interest of $0.59, balance = 31.32
# 2028-03-01: Payment of $8, balance = 23.32
# 2028-04-01: Accrued interest of $0.48, balance = 23.8
# 2028-04-01: Payment of $8, balance = 15.8
# 2028-05-01: Accrued interest of $0.31, balance = 16.11
# 2028-05-01: Payment of $8, balance = 8.11
# 2028-06-01: Accrued interest of $0.17, balance = 8.28
# 2028-06-01: Payment of $8, balance = 0.28
# 2028-07-01: Accrued interest of $0.01, balance = 0.29
# 2028-07-01: Payment of $0.29, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-11-01: Accrued interest of $3.99, balance = 199.86
# 2025-11-01: Payment of $8, balance = 191.86
# 2025-12-01: Accrued interest of $3.78, balance = 195.64
# 2025-12-01: Payment of $8, balance = 187.64
# 2026-01-01: Accrued interest of $3.82, balance = 191.46
# 2026-01-01: Payment of $8, balance = 183.46
# 2026-02-01: Accrued interest of $3.74, balance = 187.2
# 2026-03-01: Accrued interest of $3.45, balance = 190.65
# 2026-04-01: Accrued interest of $3.89, balance = 194.54
# 2026-05-01: Accrued interest of $3.84, balance = 198.38
# 2026-05-01: Payment of $8, balance = 190.38
# 2026-06-01: Accrued interest of $3.88, balance = 194.26
# 2026-06-01: Payment of $8, balance = 186.26
# 2026-07-01: Accrued interest of $3.67, balance = 189.93
# 2026-07-01: Payment of $8, balance = 181.93
# 2026-08-01: Accrued interest of $3.71, balance = 185.64
# 2026-08-01: Payment of $8, balance = 177.64
# 2026-09-01: Accrued interest of $3.62, balance = 181.26
# 2026-09-01: Payment of $8, balance = 173.26
# 2026-10-01: Accrued interest of $3.42, balance = 176.68
# 2026-10-01: Payment of $8, balance = 168.68
# 2026-11-01: Accrued interest of $3.44, balance = 172.12
# 2026-11-01: Payment of $8, balance = 164.12
# 2026-12-01: Accrued interest of $3.24, balance = 167.36
# 2026-12-01: Payment of $8, balance = 159.36
# 2027-01-01: Accrued interest of $3.25, balance = 162.61
# 2027-01-01: Payment of $8, balance = 154.61
# 2027-02-01: Accrued interest of $3.15, balance = 157.76
# 2027-02-01: Payment of $8, balance = 149.76
# 2027-03-01: Accrued interest of $2.76, balance = 152.52
# 2027-03-01: Payment of $8, balance = 144.52
# 2027-04-01: Accrued interest of $2.95, balance = 147.47
# 2027-04-01: Payment of $8, balance = 139.47
# 2027-05-01: Accrued interest of $2.75, balance = 142.22
# 2027-05-01: Payment of $8, balance = 134.22
# 2027-06-01: Accrued interest of $2.74, balance = 136.96
# 2027-06-01: Payment of $8, balance = 128.96
# 2027-07-01: Accrued interest of $2.54, balance = 131.5
# 2027-07-01: Payment of $8, balance = 123.5
# 2027-08-01: Accrued interest of $2.52, balance = 126.02
# 2027-08-01: Payment of $8, balance = 118.02
# 2027-09-01: Accrued interest of $2.41, balance = 120.43
# 2027-09-01: Payment of $8, balance = 112.43
# 2027-10-01: Accrued interest of $2.22, balance = 114.65
# 2027-10-01: Payment of $8, balance = 106.65
# 2027-11-01: Accrued interest of $2.17, balance = 108.82
# 2027-11-01: Payment of $8, balance = 100.82
# 2027-12-01: Accrued interest of $1.99, balance = 102.81
# 2028-01-01: Accrued interest of $2.1, balance = 104.91
# ...
# 2028-07-01: Accrued interest of $0.01, balance = 0.29
# 2028-07-01: Payment of $0.29, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-08-01: Payment of $8, balance = 196.08
# 2025-09-01: Accrued interest of $4.0, balance = 200.08
# 2025-09-01: Payment of $8, balance = 192.08
# 2025-10-01: Accrued interest of $3.79, balance = 195.87
# 2025-11-01: Accrued interest of $3.99, balance = 199.86
# 2025-11-01: Payment of $8, balance = 191.86
# 2025-12-01: Accrued interest of $3.78, balance = 195.64
# 2025-12-01: Payment of $8, balance = 187.64
# 2026-01-01: Accrued interest of $3.82, balance = 191.46
# 2026-01-01: Payment of $8, balance = 183.46
# 2026-02-01: Accrued interest of $3.74, balance = 187.2
# 2026-02-01: Payment of $8, balance = 179.2
# 2026-03-01: Accrued interest of $3.3, balance = 182.5
# 2026-03-01: Payment of $8, balance = 174.5
# 2026-04-01: Accrued interest of $3.56, balance = 178.06
# 2026-04-01: Payment of $8, balance = 170.06
# 2026-05-01: Accrued interest of $3.35, balance = 173.41
# 2026-05-01: Payment of $8, balance = 165.41
# 2026-06-01: Accrued interest of $3.37, balance = 168.78
# 2026-06-01: Payment of $8, balance = 160.78
# 2026-07-01: Accrued interest of $3.17, balance = 163.95
# 2026-07-01: Payment of $8, balance = 155.95
# 2026-08-01: Accrued interest of $3.18, balance = 159.13
# 2026-08-01: Payment of $8, balance = 151.13
# 2026-09-01: Accrued interest of $3.08, balance = 154.21
# 2026-09-01: Payment of $8, balance = 146.21
# 2026-10-01: Accrued interest of $2.88, balance = 149.09
# 2026-10-01: Payment of $8, balance = 141.09
# 2026-11-01: Accrued interest of $2.88, balance = 143.97
# 2026-11-01: Payment of $8, balance = 135.97
# 2026-12-01: Accrued interest of $2.68, balance = 138.65
# 2026-12-01: Payment of $8, balance = 130.65
# 2027-01-01: Accrued interest of $2.66, balance = 133.31
# 2027-02-01: Accrued interest of $2.72, balance = 136.03
# 2027-02-01: Payment of $8, balance = 128.03
# 2027-03-01: Accrued interest of $2.36, balance = 130.39
# 2027-03-01: Payment of $8, balance = 122.39
# 2027-04-01: Accrued interest of $2.49, balance = 124.88
# 2027-04-01: Payment of $8, balance = 116.88
# 2027-05-01: Accrued interest of $2.31, balance = 119.19
# 2027-05-01: Payment of $8, balance = 111.19
# 2027-06-01: Accrued interest of $2.27, balance = 113.46
# 2027-07-01: Accrued interest of $2.24, balance = 115.7
# 2027-07-01: Payment of $8, balance = 107.7
# 2027-08-01: Accrued interest of $2.2, balance = 109.9
# 2027-08-01: Payment of $8, balance = 101.9
# 2027-09-01: Accrued interest of $2.08, balance = 103.98
# 2027-09-01: Payment of $8, balance = 95.98
# 2027-10-01: Accrued interest of $1.89, balance = 97.87
# 2027-10-01: Payment of $8, balance = 89.87
# 2027-11-01: Accrued interest of $1.83, balance = 91.7
# 2027-12-01: Accrued interest of $1.81, balance = 93.51
# 2028-01-01: Accrued interest of $1.91, balance = 95.42
# 2028-01-01: Payment of $8, balance = 87.42
# 2028-02-01: Accrued interest of $1.78, balance = 89.2
# 2028-02-01: Payment of $8, balance = 81.2
# 2028-03-01: Accrued interest of $1.55, balance = 82.75
# 2028-03-01: Payment of $8, balance = 74.75
# 2028-04-01: Accrued interest of $1.52, balance = 76.27
# 2028-04-01: Payment of $8, balance = 68.27
# 2028-05-01: Accrued interest of $1.35, balance = 69.62
# 2028-05-01: Payment of $8, balance = 61.62
# 2028-06-01: Accrued interest of $1.26, balance = 62.88
# 2028-06-01: Payment of $8, balance = 54.88
# 2028-07-01: Accrued interest of $1.08, balance = 55.96
# 2028-08-01: Accrued interest of $1.14, balance = 57.1
# 2028-08-01: Payment of $8, balance = 49.1
# 2028-09-01: Accrued interest of $1.0, balance = 50.1
# 2028-09-01: Payment of $8, balance = 42.1
# 2028-10-01: Accrued interest of $0.83, balance = 42.93
# 2028-10-01: Payment of $8, balance = 34.93
# 2028-11-01: Accrued interest of $0.71, balance = 35.64
# 2028-11-01: Payment of $8, balance = 27.64
# 2028-12-01: Accrued interest of $0.55, balance = 28.19
# 2029-01-01: Accrued interest of $0.57, balance = 28.76
# 2029-01-01: Payment of $8, balance = 20.76
# 2029-02-01: Accrued interest of $0.42, balance = 21.18
# 2029-02-01: Payment of $8, balance = 13.18
# 2029-03-01: Accrued interest of $0.24, balance = 13.42
# 2029-03-01: Payment of $8, balance = 5.42
# 2029-04-01: Accrued interest of $0.11, balance = 5.53
# 2029-04-01: Payment of $5.53, balance = 0.0
#           Ledger for Loan of $200 with annual rate 24.0%
#
# 2025-07-01: Initial loan of $200, balance = 200
# 2025-08-01: Accrued interest of $4.08, balance = 204.08
# 2025-09-01: Accrued interest of $4.16, balance = 208.24
# 2025-10-01: Accrued interest of $4.11, balance = 212.35
# 2025-10-01: Payment of $8, balance = 204.35
# 2025-11-01: Accrued interest of $4.17, balance = 208.52
# 2025-11-01: Payment of $8, balance = 200.52
# 2025-12-01: Accrued interest of $3.96, balance = 204.48
# 2026-01-01: Accrued interest of $4.17, balance = 208.65
# 2026-01-01: Payment of $8, balance = 200.65
# 2026-02-01: Accrued interest of $4.09, balance = 204.74
# 2026-03-01: Accrued interest of $3.77, balance = 208.51
# 2026-03-01: Payment of $8, balance = 200.51
# 2026-04-01: Accrued interest of $4.09, balance = 204.6
# 2026-04-01: Payment of $8, balance = 196.6
# 2026-05-01: Accrued interest of $3.88, balance = 200.48
# 2026-05-01: Payment of $8, balance = 192.48
# 2026-06-01: Accrued interest of $3.92, balance = 196.4
# 2026-07-01: Accrued interest of $3.87, balance = 200.27
# 2026-08-01: Accrued interest of $4.08, balance = 204.35
# 2026-08-01: Payment of $8, balance = 196.35
# 2026-09-01: Accrued interest of $4.0, balance = 200.35
# 2026-09-01: Payment of $8, balance = 192.35
# 2026-10-01: Accrued interest of $3.79, balance = 196.14
# 2026-10-01: Payment of $8, balance = 188.14
# 2026-11-01: Accrued interest of $3.83, balance = 191.97
# 2026-12-01: Accrued interest of $3.79, balance = 195.76
# 2026-12-01: Payment of $8, balance = 187.76
# 2027-01-01: Accrued interest of $3.83, balance = 191.59
# 2027-02-01: Accrued interest of $3.91, balance = 195.5
# 2027-02-01: Payment of $8, balance = 187.5
# 2027-03-01: Accrued interest of $3.45, balance = 190.95
# 2027-03-01: Payment of $8, balance = 182.95
# 2027-04-01: Accrued interest of $3.73, balance = 186.68
# 2027-05-01: Accrued interest of $3.68, balance = 190.36
# 2027-06-01: Accrued interest of $3.88, balance = 194.24
# 2027-07-01: Accrued interest of $3.83, balance = 198.07
# 2027-08-01: Accrued interest of $4.04, balance = 202.11
# 2027-09-01: Accrued interest of $4.12, balance = 206.23
# 2027-09-01: Payment of $8, balance = 198.23
# 2027-10-01: Accrued interest of $3.91, balance = 202.14
# 2027-11-01: Accrued interest of $4.12, balance = 206.26
# 2027-11-01: Payment of $8, balance = 198.26
# 2027-12-01: Accrued interest of $3.91, balance = 202.17
# 2028-01-01: Accrued interest of $4.12, balance = 206.29
# 2028-01-01: Payment of $8, balance = 198.29
# 2028-02-01: Accrued interest of $4.04, balance = 202.33
# 2028-03-01: Accrued interest of $3.86, balance = 206.19
# 2028-04-01: Accrued interest of $4.2, balance = 210.39
# 2028-05-01: Accrued interest of $4.15, balance = 214.54
# 2028-05-01: Payment of $8, balance = 206.54
# 2028-06-01: Accrued interest of $4.21, balance = 210.75
# 2028-07-01: Accrued interest of $4.16, balance = 214.91
# 2028-07-01: Payment of $8, balance = 206.91
# 2028-08-01: Accrued interest of $4.22, balance = 211.13
# 2028-09-01: Accrued interest of $4.3, balance = 215.43
# 2028-10-01: Accrued interest of $4.25, balance = 219.68
# 2028-10-01: Payment of $8, balance = 211.68
# 2028-11-01: Accrued interest of $4.31, balance = 215.99
# 2028-12-01: Accrued interest of $4.26, balance = 220.25
# 2028-12-01: Payment of $8, balance = 212.25
# 2029-01-01: Accrued interest of $4.33, balance = 216.58
# 2029-01-01: Payment of $8, balance = 208.58
# 2029-02-01: Accrued interest of $4.25, balance = 212.83
# 2029-03-01: Accrued interest of $3.92, balance = 216.75
# 2029-04-01: Accrued interest of $4.42, balance = 221.17
# 2029-04-01: Payment of $8, balance = 213.17
# 2029-05-01: Accrued interest of $4.2, balance = 217.37
# 2029-06-01: Accrued interest of $4.43, balance = 221.8
# 2029-06-01: Payment of $8, balance = 213.8
# 2029-07-01: Accrued interest of $4.22, balance = 218.02
# 2029-07-01: Payment of $8, balance = 210.02
# 2029-08-01: Accrued interest of $4.28, balance = 214.3
# 2029-08-01: Payment of $8, balance = 206.3
# 2029-09-01: Accrued interest of $4.21, balance = 210.51
# 2029-10-01: Accrued interest of $4.15, balance = 214.66
# 2029-11-01: Accrued interest of $4.38, balance = 219.04
# 2029-11-01: Payment of $8, balance = 211.04
# 2029-12-01: Accrued interest of $4.16, balance = 215.2
# 2030-01-01: Accrued interest of $4.39, balance = 219.59
# 2030-02-01: Accrued interest of $4.48, balance = 224.07
# 2030-03-01: Accrued interest of $4.13, balance = 228.2
# 2030-04-01: Accrued interest of $4.65, balance = 232.85
# 2030-05-01: Accrued interest of $4.59, balance = 237.44
# 2030-05-01: Payment of $8, balance = 229.44
# 2030-06-01: Accrued interest of $4.68, balance = 234.12
# 2030-07-01: Accrued interest of $4.62, balance = 238.74
# 2030-08-01: Accrued interest of $4.87, balance = 243.61
# 2030-09-01: Accrued interest of $4.97, balance = 248.58
# 2030-09-01: Payment of $8, balance = 240.58
# 2030-10-01: Accrued interest of $4.75, balance = 245.33
# 2030-11-01: Accrued interest of $5.0, balance = 250.33
# 2030-12-01: Accrued interest of $4.94, balance = 255.27
# 2031-01-01: Accrued interest of $5.2, balance = 260.47
# 2031-01-01: Payment of $8, balance = 252.47
# 2031-02-01: Accrued interest of $5.15, balance = 257.62
# 2031-03-01: Accrued interest of $4.74, balance = 262.36
# 2031-04-01: Accrued interest of $5.35, balance = 267.71
# 2031-04-01: Payment of $8, balance = 259.71
# 2031-05-01: Accrued interest of $5.12, balance = 264.83
# 2031-05-01: Payment of $8, balance = 256.83
# 2031-06-01: Accrued interest of $5.24, balance = 262.07
# 2031-06-01: Payment of $8, balance = 254.07
# 2031-07-01: Accrued interest of $5.01, balance = 259.08
# 2031-07-01: Payment of $8, balance = 251.08
# 2031-08-01: Accrued interest of $5.12, balance = 256.2
# 2031-09-01: Accrued interest of $5.22, balance = 261.42
# 2031-10-01: Accrued interest of $5.16, balance = 266.58
# 2031-10-01: Payment of $8, balance = 258.58
# 2031-11-01: Accrued interest of $5.27, balance = 263.85
# 2031-12-01: Accrued interest of $5.2, balance = 269.05
# 2031-12-01: Payment of $8, balance = 261.05
# 2032-01-01: Accrued interest of $5.32, balance = 266.37
# 2032-01-01: Payment of $8, balance = 258.37
# 2032-02-01: Accrued interest of $5.27, balance = 263.64
# 2032-03-01: Accrued interest of $5.03, balance = 268.67
# 2032-03-01: Payment of $8, balance = 260.67
# 2032-04-01: Accrued interest of $5.31, balance = 265.98
# 2032-05-01: Accrued interest of $5.25, balance = 271.23
# 2032-06-01: Accrued interest of $5.53, balance = 276.76
# 2032-07-01: Accrued interest of $5.46, balance = 282.22
# 2032-08-01: Accrued interest of $5.75, balance = 287.97
# 2032-08-01: Payment of $8, balance = 279.97
# 2032-09-01: Accrued interest of $5.71, balance = 285.68
# 2032-09-01: Payment of $8, balance = 277.68
# 2032-10-01: Accrued interest of $5.48, balance = 283.16
# 2032-10-01: Payment of $8, balance = 275.16
# 2032-11-01: Accrued interest of $5.61, balance = 280.77
# 2032-12-01: Accrued interest of $5.54, balance = 286.31
# 2033-01-01: Accrued interest of $5.84, balance = 292.15
# 2033-01-01: Payment of $8, balance = 284.15
# 2033-02-01: Accrued interest of $5.79, balance = 289.94
# 2033-02-01: Payment of $8, balance = 281.94
# 2033-03-01: Accrued interest of $5.19, balance = 287.13
# 2033-04-01: Accrued interest of $5.85, balance = 292.98
# 2033-05-01: Accrued interest of $5.78, balance = 298.76
# 2033-05-01: Payment of $8, balance = 290.76
# 2033-06-01: Accrued interest of $5.93, balance = 296.69
# 2033-07-01: Accrued interest of $5.85, balance = 302.54
# 2033-07-01: Payment of $8, balance = 294.54
# 2033-08-01: Accrued interest of $6.0, balance = 300.54
# 2033-08-01: Payment of $8, balance = 292.54
# 2033-09-01: Accrued interest of $5.96, balance = 298.5
# 2033-10-01: Accrued interest of $5.89, balance = 304.39
# 2033-11-01: Accrued interest of $6.2, balance = 310.59
# 2033-11-01: Payment of $8, balance = 302.59
# 2033-12-01: Accrued interest of $5.97, balance = 308.56
# 2033-12-01: Payment of $8, balance = 300.56
# 2034-01-01: Accrued interest of $6.13, balance = 306.69
# 2034-02-01: Accrued interest of $6.25, balance = 312.94
# 2034-02-01: Payment of $8, balance = 304.94
# 2034-03-01: Accrued interest of $5.61, balance = 310.55
# 2034-03-01: Payment of $8, balance = 302.55
# 2034-04-01: Accrued interest of $6.17, balance = 308.72
# 2034-04-01: Payment of $8, balance = 300.72
# 2034-05-01: Accrued interest of $5.93, balance = 306.65
# 2034-06-01: Accrued interest of $6.25, balance = 312.9
# 2034-06-01: Payment of $8, balance = 304.9
# 2034-07-01: Accrued interest of $6.01, balance = 310.91
# 2034-07-01: Payment of $8, balance = 302.91
# 2034-08-01: Accrued interest of $6.17, balance = 309.08
# 2034-09-01: Accrued interest of $6.3, balance = 315.38
# 2034-09-01: Payment of $8, balance = 307.38
# 2034-10-01: Accrued interest of $6.06, balance = 313.44
# 2034-11-01: Accrued interest of $6.39, balance = 319.83
# 2034-11-01: Payment of $8, balance = 311.83
# 2034-12-01: Accrued interest of $6.15, balance = 317.98
# 2034-12-01: Payment of $8, balance = 309.98
# 2035-01-01: Accrued interest of $6.32, balance = 316.3
# 2035-01-01: Payment of $8, balance = 308.3
# 2035-02-01: Accrued interest of $6.28, balance = 314.58
# 2035-02-01: Payment of $8, balance = 306.58
# 2035-03-01: Accrued interest of $5.64, balance = 312.22
# 2035-03-01: Payment of $8, balance = 304.22
# 2035-04-01: Accrued interest of $6.2, balance = 310.42
# 2035-05-01: Accrued interest of $6.12, balance = 316.54
# 2035-06-01: Accrued interest of $6.45, balance = 322.99
# 2035-06-01: Payment of $8, balance = 314.99
# 2035-07-01: Accrued interest of $6.21, balance = 321.2
# 2035-07-01: Payment of $8, balance = 313.2
# 2035-08-01: Accrued interest of $6.38, balance = 319.58
# 2035-08-01: Payment of $8, balance = 311.58
# 2035-09-01: Accrued interest of $6.35, balance = 317.93
# 2035-10-01: Accrued interest of $6.27, balance = 324.2
# 2035-11-01: Accrued interest of $6.61, balance = 330.81
# 2035-12-01: Accrued interest of $6.53, balance = 337.34
# 2035-12-01: Payment of $8, balance = 329.34
# 2036-01-01: Accrued interest of $6.71, balance = 336.05
# 2036-01-01: Payment of $8, balance = 328.05
# 2036-02-01: Accrued interest of $6.69, balance = 334.74
# 2036-03-01: Accrued interest of $6.38, balance = 341.12
# 2036-03-01: Payment of $8, balance = 333.12
# 2036-04-01: Accrued interest of $6.79, balance = 339.91
# 2036-04-01: Payment of $8, balance = 331.91
# 2036-05-01: Accrued interest of $6.55, balance = 338.46
# 2036-05-01: Payment of $8, balance = 330.46
# 2036-06-01: Accrued interest of $6.74, balance = 337.2
# 2036-06-01: Payment of $8, balance = 329.2
# 2036-07-01: Accrued interest of $6.49, balance = 335.69
# 2036-08-01: Accrued interest of $6.84, balance = 342.53
# 2036-09-01: Accrued interest of $6.98, balance = 349.51
# 2036-10-01: Accrued interest of $6.89, balance = 356.4
# 2036-10-01: Payment of $8, balance = 348.4
# 2036-11-01: Accrued interest of $7.1, balance = 355.5
# 2036-11-01: Payment of $8, balance = 347.5
# 2036-12-01: Accrued interest of $6.85, balance = 354.35
# 2037-01-01: Accrued interest of $7.22, balance = 361.57
# 2037-02-01: Accrued interest of $7.37, balance = 368.94
# 2037-02-01: Payment of $8, balance = 360.94
# 2037-03-01: Accrued interest of $6.65, balance = 367.59
# 2037-03-01: Payment of $8, balance = 359.59
# 2037-04-01: Accrued interest of $7.33, balance = 366.92
# 2037-05-01: Accrued interest of $7.24, balance = 374.16
# 2037-05-01: Payment of $8, balance = 366.16
# 2037-06-01: Accrued interest of $7.46, balance = 373.62
# 2037-07-01: Accrued interest of $7.37, balance = 380.99
# 2037-08-01: Accrued interest of $7.77, balance = 388.76
# 2037-08-01: Payment of $8, balance = 380.76
# 2037-09-01: Accrued interest of $7.76, balance = 388.52
# 2037-09-01: Payment of $8, balance = 380.52
# 2037-10-01: Accrued interest of $7.51, balance = 388.03
# 2037-11-01: Accrued interest of $7.91, balance = 395.94
# 2037-12-01: Accrued interest of $7.81, balance = 403.75
